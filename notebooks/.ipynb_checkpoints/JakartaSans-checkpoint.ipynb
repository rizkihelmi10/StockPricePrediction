# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
sns.set()
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime 
from pandas import Series
from numpy import log

# %%
df = pd.read_csv(r'C:\Users\LENOVO\Documents\StockPricePrediction\data\raw\Data Historis Jakarta Islamic.csv')
df.head()
# Out:
#       Tanggal Terakhir Pembukaan Tertinggi Terendah   Vol. Perubahan%
# 0  08/04/2025   372,00    375,18    375,18   367,17  1,51B     -9,61%
# 1  27/03/2025   411,54    407,59    411,54   404,55  1,08B      0,68%
# 2  26/03/2025   408,77    399,44    411,19   399,44  1,49B      3,10%
# 3  25/03/2025   396,47    396,48    398,60   392,77  1,48B      0,51%
# 4  24/03/2025   394,46    406,24    406,62   381,72  1,68B     -2,96%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2420 entries, 0 to 2419
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     2420 non-null   object
#  1   Terakhir    2420 non-null   object
#  2   Pembukaan   2420 non-null   object
#  3   Tertinggi   2420 non-null   object
#  4   Terendah    2420 non-null   object
#  5   Vol.        2416 non-null   object
#  6   Perubahan%  2420 non-null   object
# dtypes: object(7)
# memory usage: 132.5+ KB

# %%
df.describe()
# Out:
#            Tanggal Terakhir Pembukaan Tertinggi Terendah   Vol. Perubahan%
# count         2420     2420      2420      2420     2420   2416       2420
# unique        2420     2308      2313      2306     2334   1543        534
# top     08/04/2025   731,14    577,42    698,08   570,10  1,11B     -0,31%
# freq             1        3         4         3        3     29         17

# %%
df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2420 entries, 0 to 2419
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     2420 non-null   datetime64[ns]
#  1   Terakhir    2420 non-null   object
#  2   Pembukaan   2420 non-null   object
#  3   Tertinggi   2420 non-null   object
#  4   Terendah    2420 non-null   object
#  5   Vol.        2416 non-null   object
#  6   Perubahan%  2420 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 132.5+ KB

# %%
def convert_volume(vol_str):
    if isinstance(vol_str, str):
        vol_str = vol_str.replace(',', '.')
        multiplier = 1
        if vol_str.endswith('B'):
            multiplier = 1_000_000_000
            vol_str = vol_str.replace('B', '')
        elif vol_str.endswith('M'):
            multiplier = 1_000_000
            vol_str = vol_str.replace('M', '')
        elif vol_str.endswith('K'):
            multiplier = 1_000
            vol_str = vol_str.replace('K', '')
        return float(vol_str) * multiplier
    return vol_str

df['Vol.'] = df['Vol.'].apply(convert_volume)

# %%
df.head()
# Out:
#      Tanggal Terakhir Pembukaan Tertinggi Terendah          Vol. Perubahan%
# 0 2025-04-08   372,00    375,18    375,18   367,17  1.510000e+09     -9,61%
# 1 2025-03-27   411,54    407,59    411,54   404,55  1.080000e+09      0,68%
# 2 2025-03-26   408,77    399,44    411,19   399,44  1.490000e+09      3,10%
# 3 2025-03-25   396,47    396,48    398,60   392,77  1.480000e+09      0,51%
# 4 2025-03-24   394,46    406,24    406,62   381,72  1.680000e+09     -2,96%

# %%
df['Terakhir'] = df['Terakhir'].astype(str).str.replace(',', '.').astype(float)
df['Pembukaan'] = df['Pembukaan'].astype(str).str.replace(',', '.').astype(float)
df['Tertinggi'] = df['Tertinggi'].astype(str).str.replace(',', '.').astype(float)
# df['Perubahan%'] = df['Perubahan%'].astype(str).str.replace(',', '.').astype(float)

# %%
df['Terendah'] = df['Terendah'].astype(str).str.replace(',', '.').astype(float)

# %%
df['Perubahan%'] = df['Perubahan%'].astype(str).str.replace('%', '').str.replace(',', '.').astype(float)

# %%
df['PriceTy'] = (df['Tertinggi'] + df['Terendah'] + df['Terakhir']) / 3
df['PriceVol'] = df['PriceTy'] * df['Vol.']
df['Cumulative'] = df['Vol.'].cumsum()
df['CumulativePriceVolume'] = df['PriceVol'].cumsum()
df['VWAP'] = df['CumulativePriceVolume'] / df['Cumulative']

# %%
df['Typical_Price'] = (df['Tertinggi'] + df['Terendah'] + df['Terakhir']) / 3
df['TPxVol'] = df['Typical_Price'] * df['Vol.']
df['Cum_TPxVol'] = df['TPxVol'].cumsum()
df['Cum_Vol'] = df['Vol.'].cumsum()
df['VWAP'] = df['Cum_TPxVol'] / df['Cum_Vol']

# %%
df.isnull().sum()
# Out:
# Tanggal                  0
# Terakhir                 0
# Pembukaan                0
# Tertinggi                0
# Terendah                 0
# Vol.                     4
# Perubahan%               0
# PriceTy                  0
# PriceVol                 4
# Cumulative               4
# CumulativePriceVolume    4
# VWAP                     4
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
DataFrame = df[['Tanggal', 'Terakhir', 'Pembukaan', 'Tertinggi', 'Terendah', 'Vol.', 'Perubahan%', 'VWAP']]

# %%
DataFrame.head(10)
# Out:
#      Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah          Vol.  \
# 0 2025-04-08    372.00     375.18     375.18    367.17  1.510000e+09
# 1 2025-03-27    411.54     407.59     411.54    404.55  1.080000e+09
# 2 2025-03-26    408.77     399.44     411.19    399.44  1.490000e+09
# 3 2025-03-25    396.47     396.48     398.60    392.77  1.480000e+09
# 4 2025-03-24    394.46     406.24     406.62    381.72  1.680000e+09
# 5 2025-03-21    406.49     413.90     414.29    403.12  2.570000e+09
# 6 2025-03-20    412.89     407.78     414.14    407.30  1.490000e+09
# 7 2025-03-19    404.89     402.92     407.69    396.07  1.300000e+09
# 8 2025-03-18    400.94     419.17     419.77    384.86  2.280000e+09
# 9 2025-03-17    417.44     415.43     420.81    415.22  1.320000e+09
#
#    Perubahan%        VWAP
# 0       -9.61  371.450000
# 1        0.68  387.195483
# 2        3.10  394.233243
# 3        0.51  394.689335
# 4       -2.96  394.591257
# 5       -1.55  398.095314
# 6        1.98  399.855363
# 7        0.98  400.167772
# 8       -3.95  400.426555
# 9        1.05  401.844070

# %%
DataFrame['VWAP'].plot()
# Out:
# <Axes: >

# %%
DataFrame.iloc[0:200]
# Out:
#        Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah          Vol.  \
# 0   2025-04-08    372.00     375.18     375.18    367.17  1.510000e+09
# 1   2025-03-27    411.54     407.59     411.54    404.55  1.080000e+09
# 2   2025-03-26    408.77     399.44     411.19    399.44  1.490000e+09
# 3   2025-03-25    396.47     396.48     398.60    392.77  1.480000e+09
# 4   2025-03-24    394.46     406.24     406.62    381.72  1.680000e+09
# ..         ...       ...        ...        ...       ...           ...
# 195 2024-06-13    496.32     502.35     503.64    496.07  7.000000e+09
# 196 2024-06-12    498.83     500.69     502.52    496.99  5.890000e+09
# 197 2024-06-11    498.26     505.89     507.32    498.26  6.540000e+09
# 198 2024-06-10    508.19     511.49     511.79    503.61  1.352000e+10
# 199 2024-06-07    511.27     517.03     518.90    510.80  2.950000e+09
#
#      Perubahan%        VWAP
# 0         -9.61  371.450000
# 1          0.68  387.195483
# 2          3.10  394.233243
# 3          0.51  394.689335
# 4         -2.96  394.591257
# ..          ...         ...
# 195       -0.50  504.040562
# 196        0.12  504.008798
# 197       -1.96  503.988008
# 198       -0.60  504.048099
# 199       -0.88  504.080498
#
# [200 rows x 8 columns]

# %%
import statsmodels.api as sm

# %%
dFrame = DataFrame[['Tanggal', 'Terakhir', 'Pembukaan', 'Tertinggi', 'Terendah', 'Vol.','VWAP']]

# %%
dFrame.head()
# Out:
#      Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah          Vol.  \
# 0 2025-04-08    372.00     375.18     375.18    367.17  1.510000e+09
# 1 2025-03-27    411.54     407.59     411.54    404.55  1.080000e+09
# 2 2025-03-26    408.77     399.44     411.19    399.44  1.490000e+09
# 3 2025-03-25    396.47     396.48     398.60    392.77  1.480000e+09
# 4 2025-03-24    394.46     406.24     406.62    381.72  1.680000e+09
#
#          VWAP
# 0  371.450000
# 1  387.195483
# 2  394.233243
# 3  394.689335
# 4  394.591257

# %%
# dFrame.dropna()
dFrame = dFrame.dropna().reset_index(drop=True)

# %%
dFrame
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah          Vol.  \
# 0    2025-04-08    372.00     375.18     375.18    367.17  1.510000e+09
# 1    2025-03-27    411.54     407.59     411.54    404.55  1.080000e+09
# 2    2025-03-26    408.77     399.44     411.19    399.44  1.490000e+09
# 3    2025-03-25    396.47     396.48     398.60    392.77  1.480000e+09
# 4    2025-03-24    394.46     406.24     406.62    381.72  1.680000e+09
# ...         ...       ...        ...        ...       ...           ...
# 2411 2015-04-13    717.43     719.20     720.84    713.53  5.811700e+08
# 2412 2015-04-10    722.08     724.44     724.59    718.09  5.134900e+08
# 2413 2015-04-09    723.85     721.60     723.85    719.43  4.559000e+08
# 2414 2015-04-08    719.99     726.52     727.51    718.39  5.924100e+08
# 2415 2015-04-07    727.56     723.80     728.28    723.54  5.749200e+08
#
#             VWAP
# 0     371.450000
# 1     387.195483
# 2     394.233243
# 3     394.689335
# 4     394.591257
# ...          ...
# 2411  581.831781
# 2412  581.851310
# 2413  581.868742
# 2414  581.891320
# 2415  581.913928
#
# [2416 rows x 7 columns]

# %%
# dFrame['VWAP'].dropna()
# dFrame['Vol.'].dropna()

# %%
dFrame['VWAP']
# Out:
# 0       371.450000
# 1       387.195483
# 2       394.233243
# 3       394.689335
# 4       394.591257
#            ...
# 2411    581.831781
# 2412    581.851310
# 2413    581.868742
# 2414    581.891320
# 2415    581.913928
# Name: VWAP, Length: 2416, dtype: float64

# %%
dFrame['Vol.']
# Out:
# 0       1.510000e+09
# 1       1.080000e+09
# 2       1.490000e+09
# 3       1.480000e+09
# 4       1.680000e+09
#             ...
# 2411    5.811700e+08
# 2412    5.134900e+08
# 2413    4.559000e+08
# 2414    5.924100e+08
# 2415    5.749200e+08
# Name: Vol., Length: 2416, dtype: float64

# %%
print(dFrame.isnull().sum())
# Out:
# Tanggal      0
# Terakhir     0
# Pembukaan    0
# Tertinggi    0
# Terendah     0
# Vol.         0
# VWAP         0
# dtype: int64

# %%
print(sm.stats.durbin_watson(dFrame['VWAP']))
print(sm.stats.durbin_watson(dFrame['Pembukaan']))
print(sm.stats.durbin_watson(dFrame['Terakhir']))
print(sm.stats.durbin_watson(dFrame['Vol.']))
print(sm.stats.durbin_watson(dFrame['Tertinggi']))
print(sm.stats.durbin_watson(dFrame['Terendah']))
# Out:
# 6.338684725004011e-07
# 0.00013639758508092597
# 0.0001390771595159202
# 0.3025879466250448
# 9.074691017887627e-05
# 0.00013079322039769384

# %%
dFrame.describe()
# Out:
#                              Tanggal     Terakhir    Pembukaan    Tertinggi  \
# count                           2416  2416.000000  2416.000000  2416.000000
# mean   2020-03-30 12:54:14.304635904   618.513974   619.083829   623.002881
# min              2015-04-07 00:00:00   372.000000   375.180000   375.180000
# 25%              2017-10-04 18:00:00   553.135000   553.127500   556.775000
# 50%              2020-03-26 12:00:00   611.530000   612.490000   616.890000
# 75%              2022-09-26 06:00:00   689.457500   689.730000   693.797500
# max              2025-04-08 00:00:00   798.770000   796.920000   799.150000
# std                              NaN    81.427398    81.353015    81.155879
#
#           Terendah          Vol.         VWAP
# count  2416.000000  2.416000e+03  2416.000000
# mean    614.176014  1.521659e+09   540.875051
# min     367.170000  2.620200e+08   371.450000
# 25%     548.650000  7.153725e+08   522.688953
# 50%     607.465000  1.010000e+09   542.207349
# 75%     685.005000  1.480000e+09   568.074504
# max     791.200000  3.491000e+10   581.913928
# std      81.462214  1.845827e+09    31.711890

# %%
dFrame.nunique()
# Out:
# Tanggal      2416
# Terakhir     2306
# Pembukaan    2311
# Tertinggi    2304
# Terendah     2332
# Vol.         1543
# VWAP         2416
# dtype: int64

# %%
dFrame1 = dFrame.copy()

# %%
dFrame1
# Out:
#             Terakhir  Pembukaan  Tertinggi  Terendah          Vol.        VWAP
# Tanggal
# 2015-04-07    727.56     723.80     728.28    723.54  5.749200e+08  581.913928
# 2015-04-08    719.99     726.52     727.51    718.39  5.924100e+08  581.891320
# 2015-04-09    723.85     721.60     723.85    719.43  4.559000e+08  581.868742
# 2015-04-10    722.08     724.44     724.59    718.09  5.134900e+08  581.851310
# 2015-04-13    717.43     719.20     720.84    713.53  5.811700e+08  581.831781
# ...              ...        ...        ...       ...           ...         ...
# 2025-03-24    394.46     406.24     406.62    381.72  1.680000e+09  394.591257
# 2025-03-25    396.47     396.48     398.60    392.77  1.480000e+09  394.689335
# 2025-03-26    408.77     399.44     411.19    399.44  1.490000e+09  394.233243
# 2025-03-27    411.54     407.59     411.54    404.55  1.080000e+09  387.195483
# 2025-04-08    372.00     375.18     375.18    367.17  1.510000e+09  371.450000
#
# [2416 rows x 6 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5440\2018035914.py in ?()
# ----> 1 dFrame1.set_index('Tanggal', inplace=True)
#
# D:\anaconda2\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['Tanggal'] are in the columns"

# %%
dFrame1
# Out:
#             Terakhir  Pembukaan  Tertinggi  Terendah          Vol.        VWAP
# Tanggal
# 2015-04-07    727.56     723.80     728.28    723.54  5.749200e+08  581.913928
# 2015-04-08    719.99     726.52     727.51    718.39  5.924100e+08  581.891320
# 2015-04-09    723.85     721.60     723.85    719.43  4.559000e+08  581.868742
# 2015-04-10    722.08     724.44     724.59    718.09  5.134900e+08  581.851310
# 2015-04-13    717.43     719.20     720.84    713.53  5.811700e+08  581.831781
# ...              ...        ...        ...       ...           ...         ...
# 2025-03-24    394.46     406.24     406.62    381.72  1.680000e+09  394.591257
# 2025-03-25    396.47     396.48     398.60    392.77  1.480000e+09  394.689335
# 2025-03-26    408.77     399.44     411.19    399.44  1.490000e+09  394.233243
# 2025-03-27    411.54     407.59     411.54    404.55  1.080000e+09  387.195483
# 2025-04-08    372.00     375.18     375.18    367.17  1.510000e+09  371.450000
#
# [2416 rows x 6 columns]

# %%
dFrame1
# Out:
#             Terakhir  Pembukaan  Tertinggi  Terendah          Vol.        VWAP
# Tanggal
# 2025-04-08    372.00     375.18     375.18    367.17  1.510000e+09  371.450000
# 2025-03-27    411.54     407.59     411.54    404.55  1.080000e+09  387.195483
# 2025-03-26    408.77     399.44     411.19    399.44  1.490000e+09  394.233243
# 2025-03-25    396.47     396.48     398.60    392.77  1.480000e+09  394.689335
# 2025-03-24    394.46     406.24     406.62    381.72  1.680000e+09  394.591257
# ...              ...        ...        ...       ...           ...         ...
# 2015-04-13    717.43     719.20     720.84    713.53  5.811700e+08  581.831781
# 2015-04-10    722.08     724.44     724.59    718.09  5.134900e+08  581.851310
# 2015-04-09    723.85     721.60     723.85    719.43  4.559000e+08  581.868742
# 2015-04-08    719.99     726.52     727.51    718.39  5.924100e+08  581.891320
# 2015-04-07    727.56     723.80     728.28    723.54  5.749200e+08  581.913928
#
# [2416 rows x 6 columns]

# %%
start_date = dFrame1.index.min()
end_date = dFrame1.index.max()

# %%
print("Start Date of Stocks :", start_date)
print("End Date of Stocks :", end_date)
# Out:
# Start Date of Stocks : 2015-04-07 00:00:00
# End Date of Stocks : 2025-04-08 00:00:00

# %%
dFrame1['VWAP'].plot()
# Out:
# <Axes: xlabel='Tanggal'>

# %%
dFrame1['Time_Stamp'] = pd.DataFrame(DataFrame, columns=['Tanggal'])

# %%
DataFrame['Tanggal']
# Out:
# 0      2025-04-08
# 1      2025-03-27
# 2      2025-03-26
# 3      2025-03-25
# 4      2025-03-24
#           ...
# 2415   2015-04-13
# 2416   2015-04-10
# 2417   2015-04-09
# 2418   2015-04-08
# 2419   2015-04-07
# Name: Tanggal, Length: 2420, dtype: datetime64[ns]

# %%
dFrame1
# Out:
#             Terakhir  Pembukaan  Tertinggi  Terendah          Vol.  \
# Tanggal
# 2015-04-07    727.56     723.80     728.28    723.54  5.749200e+08
# 2015-04-08    719.99     726.52     727.51    718.39  5.924100e+08
# 2015-04-09    723.85     721.60     723.85    719.43  4.559000e+08
# 2015-04-10    722.08     724.44     724.59    718.09  5.134900e+08
# 2015-04-13    717.43     719.20     720.84    713.53  5.811700e+08
# ...              ...        ...        ...       ...           ...
# 2025-03-24    394.46     406.24     406.62    381.72  1.680000e+09
# 2025-03-25    396.47     396.48     398.60    392.77  1.480000e+09
# 2025-03-26    408.77     399.44     411.19    399.44  1.490000e+09
# 2025-03-27    411.54     407.59     411.54    404.55  1.080000e+09
# 2025-04-08    372.00     375.18     375.18    367.17  1.510000e+09
#
#                   VWAP Time_Stamp
# Tanggal
# 2015-04-07  581.913928        NaT
# 2015-04-08  581.891320        NaT
# 2015-04-09  581.868742        NaT
# 2015-04-10  581.851310        NaT
# 2015-04-13  581.831781        NaT
# ...                ...        ...
# 2025-03-24  394.591257        NaT
# 2025-03-25  394.689335        NaT
# 2025-03-26  394.233243        NaT
# 2025-03-27  387.195483        NaT
# 2025-04-08  371.450000        NaT
#
# [2416 rows x 7 columns]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompse = seasonal_decompose(dFrame1['VWAP'],
model='additive', period=12)
decompse.plot()
plt.show()

# %%
trend = decompse.trend
seasonality = decompse.seasonal
residual = decompse.resid
print('Trend', '\n', trend.head(12),'\n')
print('Seasoanlity', '\n', seasonality.head(12),'\n')
print('Residual', '\n', residual.head(12),'\n')
# Out:
# Trend
#  Tanggal
# 2015-04-07           NaN
# 2015-04-08           NaN
# 2015-04-09           NaN
# 2015-04-10           NaN
# 2015-04-13           NaN
# 2015-04-14           NaN
# 2015-04-15    581.787822
# 2015-04-16    581.766925
# 2015-04-17    581.745950
# 2015-04-20    581.724697
# 2015-04-21    581.703021
# 2015-04-22    581.681091
# Name: trend, dtype: float64
#
# Seasoanlity
#  Tanggal
# 2015-04-07   -0.001542
# 2015-04-08    0.003859
# 2015-04-09    0.000183
# 2015-04-10    0.008675
# 2015-04-13    0.009848
# 2015-04-14    0.013990
# 2015-04-15    0.004705
# 2015-04-16   -0.009368
# 2015-04-17   -0.010824
# 2015-04-20   -0.004961
# 2015-04-21   -0.009130
# 2015-04-22   -0.005434
# Name: seasonal, dtype: float64
#
# Residual
#  Tanggal
# 2015-04-07         NaN
# 2015-04-08         NaN
# 2015-04-09         NaN
# 2015-04-10         NaN
# 2015-04-13         NaN
# 2015-04-14         NaN
# 2015-04-15   -0.006049
# 2015-04-16    0.010814
# 2015-04-17    0.009581
# 2015-04-20    0.003167
# 2015-04-21    0.010481
# 2015-04-22    0.008335
# Name: resid, dtype: float64

# %%
dFrame1['Bulan'] = dFrame1.index.month
dFrame1['Tahun'] = dFrame1.index.year
# dFrame1.head()
dFrame1.tail()
# Out:
#             Terakhir  Pembukaan  Tertinggi  Terendah          Vol.  \
# Tanggal
# 2025-03-24    394.46     406.24     406.62    381.72  1.680000e+09
# 2025-03-25    396.47     396.48     398.60    392.77  1.480000e+09
# 2025-03-26    408.77     399.44     411.19    399.44  1.490000e+09
# 2025-03-27    411.54     407.59     411.54    404.55  1.080000e+09
# 2025-04-08    372.00     375.18     375.18    367.17  1.510000e+09
#
#                   VWAP Time_Stamp  Bulan  Tahun
# Tanggal
# 2025-03-24  394.591257        NaT      3   2025
# 2025-03-25  394.689335        NaT      3   2025
# 2025-03-26  394.233243        NaT      3   2025
# 2025-03-27  387.195483        NaT      3   2025
# 2025-04-08  371.450000        NaT      4   2025

# %%
dFrame1['VWAP_diff'] = dFrame1['VWAP'].diff().dropna().reset_index(drop=True)

# %%
dFrame1
# Out:
#             Terakhir  Pembukaan  Tertinggi  Terendah          Vol.  \
# Tanggal
# 2015-04-07    727.56     723.80     728.28    723.54  5.749200e+08
# 2015-04-08    719.99     726.52     727.51    718.39  5.924100e+08
# 2015-04-09    723.85     721.60     723.85    719.43  4.559000e+08
# 2015-04-10    722.08     724.44     724.59    718.09  5.134900e+08
# 2015-04-13    717.43     719.20     720.84    713.53  5.811700e+08
# ...              ...        ...        ...       ...           ...
# 2025-03-24    394.46     406.24     406.62    381.72  1.680000e+09
# 2025-03-25    396.47     396.48     398.60    392.77  1.480000e+09
# 2025-03-26    408.77     399.44     411.19    399.44  1.490000e+09
# 2025-03-27    411.54     407.59     411.54    404.55  1.080000e+09
# 2025-04-08    372.00     375.18     375.18    367.17  1.510000e+09
#
#                   VWAP Time_Stamp  Bulan  Tahun
# Tanggal
# 2015-04-07  581.913928        NaT      4   2015
# 2015-04-08  581.891320        NaT      4   2015
# 2015-04-09  581.868742        NaT      4   2015
# 2015-04-10  581.851310        NaT      4   2015
# 2015-04-13  581.831781        NaT      4   2015
# ...                ...        ...    ...    ...
# 2025-03-24  394.591257        NaT      3   2025
# 2025-03-25  394.689335        NaT      3   2025
# 2025-03-26  394.233243        NaT      3   2025
# 2025-03-27  387.195483        NaT      3   2025
# 2025-04-08  371.450000        NaT      4   2025
#
# [2416 rows x 9 columns]

# %%
dFrame1.index.min()
dFrame1.index.max()
# Out:
# Timestamp('2025-04-08 00:00:00')

# %%
dFrame = dFrame.sort_index(ascending=True)

# Now do the split
split_date = dFrame.index[int(len(dFrame) * 0.8)]
train = dFrame[:split_date]
test = dFrame[split_date:]

print(f"Train data: {train.index[0]} to {train.index[-1]}")
print(f"Test data : {test.index[0]} to {test.index[-1]}")
# Out:
# Train data: 2015-04-07 00:00:00 to 2023-03-15 00:00:00
# Test data : 2023-03-15 00:00:00 to 2025-04-08 00:00:00

# %%
train['VWAP']
# Out:
# Tanggal
# 2015-04-07    581.913928
# 2015-04-08    581.891320
# 2015-04-09    581.868742
# 2015-04-10    581.851310
# 2015-04-13    581.831781
#                  ...
# 2023-03-09    517.105249
# 2023-03-10    517.083782
# 2023-03-13    517.062950
# 2023-03-14    517.036382
# 2023-03-15    517.001425
# Name: VWAP, Length: 1933, dtype: float64

# %%
test['VWAP']
# Out:
# Tanggal
# 2023-03-15    517.001425
# 2023-03-16    516.976890
# 2023-03-17    516.953339
# 2023-03-20    516.921622
# 2023-03-21    516.898388
#                  ...
# 2025-03-24    394.591257
# 2025-03-25    394.689335
# 2025-03-26    394.233243
# 2025-03-27    387.195483
# 2025-04-08    371.450000
# Name: VWAP, Length: 484, dtype: float64

# %%
from statsmodels.tsa.stattools import adfuller
adfuller(train['VWAP'])
# Out:
# (0.16385448700261107,
#  0.9701598588879178,
#  19,
#  1913,
#  {'1%': -3.433772946369569,
#   '5%': -2.8630520356606137,
#   '10%': -2.567574949489954},
#  -11364.409471243778)

# %%
def check_adftest(timeseries):
    result = adfuller(timeseries)
    print("Augmented Dickey-Fuller Test")
    labels = ['ADF Test Statistic', 'P-Value', '#Lags Used', 'Number of Observations Used']
    
    for label, value in zip(labels, result[:4]):
        print(f"{label} -----> {value}")
    
    if result[1] <= 0.05:
        print("\nStrong evidence against the null hypothesis (unit root). The time series is **stationary**.")
    else:
        print("\nWeak evidence against the null hypothesis. The time series is **non-stationary**.")
        
check_adftest(train['VWAP'])
# Out:
# Augmented Dickey-Fuller Test
# ADF Test Statistic -----> 0.16385448700261107
# P-Value -----> 0.9701598588879178
# #Lags Used -----> 19
# Number of Observations Used -----> 1913
#
# Weak evidence against the null hypothesis. The time series is **non-stationary**.

# %%
import numpy as np

# %%
dFrameDiff = dFrame1.copy()

# %%
dFrameDiff['log_VWAP'] = np.log(dFrameDiff['VWAP'])

# %%
def make_stationary(series):
    
    differenced_series = series.diff().dropna()
    return differenced_series


vwap_diff = make_stationary(train['VWAP'])


check_adftest(vwap_diff)

# %%
dFrameDiff
# Out:
#             Terakhir  Pembukaan  Tertinggi  Terendah          Vol.  \
# Tanggal
# 2015-04-07    727.56     723.80     728.28    723.54  5.749200e+08
# 2015-04-08    719.99     726.52     727.51    718.39  5.924100e+08
# 2015-04-09    723.85     721.60     723.85    719.43  4.559000e+08
# 2015-04-10    722.08     724.44     724.59    718.09  5.134900e+08
# 2015-04-13    717.43     719.20     720.84    713.53  5.811700e+08
# ...              ...        ...        ...       ...           ...
# 2025-03-24    394.46     406.24     406.62    381.72  1.680000e+09
# 2025-03-25    396.47     396.48     398.60    392.77  1.480000e+09
# 2025-03-26    408.77     399.44     411.19    399.44  1.490000e+09
# 2025-03-27    411.54     407.59     411.54    404.55  1.080000e+09
# 2025-04-08    372.00     375.18     375.18    367.17  1.510000e+09
#
#                   VWAP Time_Stamp  Bulan  Tahun  log_VWAP
# Tanggal
# 2015-04-07  581.913928        NaT      4   2015  6.366323
# 2015-04-08  581.891320        NaT      4   2015  6.366284
# 2015-04-09  581.868742        NaT      4   2015  6.366245
# 2015-04-10  581.851310        NaT      4   2015  6.366215
# 2015-04-13  581.831781        NaT      4   2015  6.366181
# ...                ...        ...    ...    ...       ...
# 2025-03-24  394.591257        NaT      3   2025  5.977850
# 2025-03-25  394.689335        NaT      3   2025  5.978099
# 2025-03-26  394.233243        NaT      3   2025  5.976943
# 2025-03-27  387.195483        NaT      3   2025  5.958930
# 2025-04-08  371.450000        NaT      4   2025  5.917414
#
# [2416 rows x 10 columns]

# %%
dFrameDiff = dFrameDiff.sort_index(ascending=True)

# Now do the split
split_date = dFrameDiff.index[int(len(dFrameDiff) * 0.8)]
train = dFrameDiff[:split_date]
test = dFrameDiff[split_date:]

print(f"Train data: {train.index[0]} to {train.index[-1]}")
print(f"Test data : {test.index[0]} to {test.index[-1]}")
# Out:
# Train data: 2015-04-07 00:00:00 to 2023-03-15 00:00:00
# Test data : 2023-03-15 00:00:00 to 2025-04-08 00:00:00

# %%
train['log_VWAP']
# Out:
# Tanggal
# 2015-04-07    6.366323
# 2015-04-08    6.366284
# 2015-04-09    6.366245
# 2015-04-10    6.366215
# 2015-04-13    6.366181
#                 ...
# 2023-03-09    6.248246
# 2023-03-10    6.248205
# 2023-03-13    6.248165
# 2023-03-14    6.248113
# 2023-03-15    6.248046
# Name: log_VWAP, Length: 1933, dtype: float64

# %%
check_adftest(train['log_VWAP'])
# Out:
# Augmented Dickey-Fuller Test
# ADF Test Statistic -----> 0.31638077091679073
# P-Value -----> 0.9780836697441652
# #Lags Used -----> 19
# Number of Observations Used -----> 1913
#
# Weak evidence against the null hypothesis. The time series is **non-stationary**.

# %%
vwap_diff
# Out:
# Tanggal
# 2015-04-08   -0.022608
# 2015-04-09   -0.022579
# 2015-04-10   -0.017432
# 2015-04-13   -0.019529
# 2015-04-14   -0.021426
#                 ...
# 2023-03-09   -0.025358
# 2023-03-10   -0.021467
# 2023-03-13   -0.020832
# 2023-03-14   -0.026568
# 2023-03-15   -0.034957
# Name: VWAP, Length: 1932, dtype: float64

# %%
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# %% [raw]
# !pip install pmdarima

# %%
kurtosis_value = vwap_diff.kurtosis()

# %%
print(kurtosis_value)
# Out:
# 4.712208036844876

# %%
from pmdarima import auto_arima

# %%
auto_model = auto_arima(vwap_diff, seasonal=False, trace=True)
print(auto_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-11474.514, Time=3.35 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-11003.181, Time=0.62 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-11266.952, Time=0.98 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-11455.323, Time=1.63 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-11005.181, Time=0.26 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-11476.848, Time=1.62 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-11478.473, Time=1.27 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-11476.060, Time=0.98 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-11474.058, Time=1.19 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-11482.116, Time=0.89 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-11484.336, Time=5.43 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-11484.097, Time=1.32 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=-11479.620, Time=4.56 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-11485.502, Time=4.15 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-11484.790, Time=1.74 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=-11484.203, Time=2.52 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=-11486.721, Time=2.28 sec
#  ARIMA(0,1,5)(0,0,0)[0]             : AIC=-11490.049, Time=2.05 sec
#  ARIMA(0,1,4)(0,0,0)[0]             : AIC=-11488.420, Time=2.45 sec
#  ARIMA(1,1,5)(0,0,0)[0]             : AIC=-11487.580, Time=1.61 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=-11487.502, Time=0.47 sec
#
# Best model:  ARIMA(0,1,5)(0,0,0)[0]
# Total fit time: 41.405 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1932
# Model:               SARIMAX(0, 1, 5)   Log Likelihood                5751.025
# Date:                Thu, 10 Apr 2025   AIC                         -11490.049
# Time:                        09:44:20   BIC                         -11456.654
# Sample:                             0   HQIC                        -11477.765
#                                - 1932
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5163      0.012    -42.299      0.000      -0.540      -0.492
# ma.L2         -0.1094      0.016     -6.907      0.000      -0.140      -0.078
# ma.L3         -0.0592      0.016     -3.747      0.000      -0.090      -0.028
# ma.L4          0.0992      0.016      6.073      0.000       0.067       0.131
# ma.L5         -0.0449      0.015     -3.014      0.003      -0.074      -0.016
# sigma2         0.0002    2.1e-06     72.074      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              7224.72
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.42   Skew:                            -1.16
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model = ARIMA(vwap_diff, order=(0,1,5))
result = model.fit()
print(result.summary())
# Out:
# D:\anaconda2\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\anaconda2\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\anaconda2\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   VWAP   No. Observations:                 1932
# Model:                 ARIMA(0, 1, 5)   Log Likelihood                5751.025
# Date:                Thu, 10 Apr 2025   AIC                         -11490.049
# Time:                        09:44:29   BIC                         -11456.654
# Sample:                             0   HQIC                        -11477.765
#                                - 1932
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5163      0.012    -42.299      0.000      -0.540      -0.492
# ma.L2         -0.1094      0.016     -6.907      0.000      -0.140      -0.078
# ma.L3         -0.0592      0.016     -3.747      0.000      -0.090      -0.028
# ma.L4          0.0992      0.016      6.073      0.000       0.067       0.131
# ma.L5         -0.0449      0.015     -3.014      0.003      -0.074      -0.016
# sigma2         0.0002    2.1e-06     72.074      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              7224.72
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.42   Skew:                            -1.16
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
result.plot_diagnostics(figsize=(12, 6))
plt.show()
